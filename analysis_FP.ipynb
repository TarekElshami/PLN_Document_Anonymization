# %%
from analysis_FP import procesar_txt

procesar_txt("errores_noMargen/no_tags/errores_prompt8.txt")
# Out:
# Top 15 Falsos Positivos más repetidos (normalizados):
#
# nhc: 32
# dra: 20
# hospital: 20
# nefrologia: 19
# cp: 16
# 6 meses: 13
# urologia: 10
# nass: 10
# dr: 9
# nocol: 8
# 2004: 5
# neurologia: 5
# 3 meses: 5
# farmacia: 5
# cirugia maxilofacial: 5

# %%
procesar_txt("errores_noMargen/with_tags/errores_prompt8.txt")
# Out:
# Top 15 Falsos Positivos más repetidos (normalizados):
#
# nhc: 32
# dra: 20
# hospital: 20
# nefrologia: 19
# espana: 15
# cp: 14
# 6 meses: 13
# urologia: 10
# nass: 10
# dr: 9
# nocol: 8
# 2004: 5
# 3 anos: 5
# neurologia: 5
# 3 meses: 5
